# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import mplleaflet

# import cartopy.crs as ccrs
# import cartopy.mpl.ticker as cticker
# import cartopy.feature as feature
# from cartopy.util import add_cyclic_point

# %%
file_dir = "/scratch/vreddy6/resolution-test/"
file1_name = "F.1850x2.0_C5_280_ihesp1046.01_ANN_concat.nc"
file2_name = "F.1850x1.0_C5_280_ihesp1046.01_ANN_concat.nc"
file3_name = "F.1850x0.25_C5_280_ihesp1046.01_ANN_concat.nc"

ds1 = xr.open_dataset(file_dir + file1_name)
ds2 = xr.open_dataset(file_dir + file2_name)
ds3 = xr.open_dataset(file_dir + file3_name)

# %%
ds2
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 12, lat: 192, lon: 288, lev: 30, ilev: 31, slat: 191, slon: 288, nbnd: 2)
# Coordinates:
#   * ilev           (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * lat            (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lev            (lev) float64 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * lon            (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * slat           (slat) float64 -89.53 -88.59 -87.64 ... 87.64 88.59 89.53
#   * slon           (slon) float64 -0.625 0.625 1.875 3.125 ... 355.6 356.9 358.1
#   * time           (time) object 0010-08-02 12:00:00 ... 0011-07-02 12:00:00
# Dimensions without coordinates: nbnd
# Data variables: (12/167)
#     AEROD_v        (time, lat, lon) float32 ...
#     ANRAIN         (time, lev, lat, lon) float32 ...
#     ANSNOW         (time, lev, lat, lon) float32 ...
#     AODDUST1       (time, lat, lon) float32 ...
# ...

# %%
ds3
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 12, lat: 768, lon: 1152, lev: 30, ilev: 31, slat: 767, slon: 1152, nbnd: 2)
# Coordinates:
#   * ilev           (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * lat            (lat) float64 -90.0 -89.77 -89.53 -89.3 ... 89.53 89.77 90.0
#   * lev            (lev) float64 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * lon            (lon) float64 0.0 0.3125 0.625 0.9375 ... 359.1 359.4 359.7
#   * slat           (slat) float64 -89.88 -89.65 -89.41 ... 89.41 89.65 89.88
#   * slon           (slon) float64 -0.1562 0.1562 0.4688 ... 358.9 359.2 359.5
#   * time           (time) object 0010-08-02 12:00:00 ... 0011-07-02 12:00:00
# Dimensions without coordinates: nbnd
# Data variables: (12/167)
#     AEROD_v        (time, lat, lon) float32 ...
#     ANRAIN         (time, lev, lat, lon) float32 ...
#     ANSNOW         (time, lev, lat, lon) float32 ...
#     AODDUST1       (time, lat, lon) float32 ...
# ...

# %%
ds2_mean = ds2.mean(dim='time')

# %%
ds2_mean
# Out:
# <xarray.Dataset>
# Dimensions:        (lat: 192, lon: 288, lev: 30, ilev: 31, slat: 191, slon: 288)
# Coordinates:
#   * ilev           (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * lat            (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lev            (lev) float64 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * lon            (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * slat           (slat) float64 -89.53 -88.59 -87.64 ... 87.64 88.59 89.53
#   * slon           (slon) float64 -0.625 0.625 1.875 3.125 ... 355.6 356.9 358.1
# Data variables: (12/164)
#     AEROD_v        (lat, lon) float32 0.007628 0.007628 ... 0.01264 0.01264
#     ANRAIN         (lev, lat, lon) float32 0.0 0.0 0.0 ... 2.225e+03 2.225e+03
#     ANSNOW         (lev, lat, lon) float32 0.0 0.0 0.0 ... 1.581e+03 1.581e+03
#     AODDUST1       (lat, lon) float32 3.339e-05 3.339e-05 ... 0.0008804
# ...

# %%
ts = ds2.TS
ts.lat
# Out:
# <xarray.DataArray 'lat' (lat: 192)>
# array([-90.      , -89.057592, -88.115183, -87.172775, -86.230366, -85.287958,
#        -84.34555 , -83.403141, -82.460733, -81.518325, -80.575916, -79.633508,
#        -78.691099, -77.748691, -76.806283, -75.863874, -74.921466, -73.979058,
#        -73.036649, -72.094241, -71.151832, -70.209424, -69.267016, -68.324607,
#        -67.382199, -66.439791, -65.497382, -64.554974, -63.612565, -62.670157,
#        -61.727749, -60.78534 , -59.842932, -58.900524, -57.958115, -57.015707,
#        -56.073298, -55.13089 , -54.188482, -53.246073, -52.303665, -51.361257,
#        -50.418848, -49.47644 , -48.534031, -47.591623, -46.649215, -45.706806,
#        -44.764398, -43.82199 , -42.879581, -41.937173, -40.994764, -40.052356,
#        -39.109948, -38.167539, -37.225131, -36.282723, -35.340314, -34.397906,
#        -33.455497, -32.513089, -31.570681, -30.628272, -29.685864, -28.743455,
# ...

# %%
ts_ann = ts.mean(dim='time')

# %%
import matplotlib.pyplot as plt
import mplleaflet

# Assuming ts_ann is your data
fig, ax = plt.subplots()  # Step 1: Create a figure and axes
contour = ax.contourf(ts_ann)  # Step 2: Plot your data on the axes

mplleaflet.show(fig=fig)  # Step 3: Pass the figure to mplleaflet.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 8>()
#       5 fig, ax = plt.subplots()  # Step 1: Create a figure and axes
#       6 contour = ax.contourf(ts_ann)  # Step 2: Plot your data on the axes
# ----> 8 mplleaflet.show(fig=fig)
#
# File ~/.conda/envs/clim_data/lib/python3.10/site-packages/mplleaflet/_display.py:180, in show(fig, path, **kwargs)
#     178 fullpath = os.path.abspath(path)
#     179 with open(fullpath, 'w') as f:
# --> 180     save_html(fig, fileobj=f, **kwargs)
#     181 webbrowser.open('file://' + fullpath)
#
# File ~/.conda/envs/clim_data/lib/python3.10/site-packages/mplleaflet/_display.py:131, in save_html(fig, fileobj, **kwargs)
#     129 if not hasattr(fileobj, 'write'):
#     130     raise ValueError("fileobj should be a filename or a writable file")
# --> 131 html = fig_to_html(fig, **kwargs)
# ...

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

data=ts_ann
data, lons = add_cyclic_point(data, coord=ts_ann['lon'])

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())

# Make a filled contour plot
ax.contourf(lons, ts_ann['lat'], data,
            transform = ccrs.PlateCarree())

# Add coastlines
ax.coastlines() 

# Define the xticks for longitude
ax.set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
lon_formatter = cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define the yticks for latitude
ax.set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
lat_formatter = cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

data=ts_ann
data, lons = add_cyclic_point(data, coord=ts_ann['lon'])

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.Robinson())

# Make a filled contour plot
ax.contourf(lons, ts_ann['lat'], data,
            transform = ccrs.Robinson(), cmap='coolwarm')

# Add coastlines
ax.coastlines() 

# # Define the xticks for longitude
# ax.set_xticks(np.arange(-180,181,60), crs=ccrs.Robinson())
# lon_formatter = cticker.LongitudeFormatter()
# ax.xaxis.set_major_formatter(lon_formatter)

# # Define the yticks for latitude
# ax.set_yticks(np.arange(-90,91,30), crs=ccrs.Robinson())
# lat_formatter = cticker.LatitudeFormatter()
# ax.yaxis.set_major_formatter(lat_formatter)

# %%
ps = ds2.PS
ps
# Out:
# <xarray.DataArray 'PS' (time: 12, lat: 192, lon: 288)>
# array([[[ 68783.07 ,  68783.07 , ...,  68783.07 ,  68783.07 ],
#         [ 69677.68 ,  69662.08 , ...,  69702.36 ,  69691.125],
#         ...,
#         [101617.5  , 101617.9  , ..., 101616.7  , 101617.125],
#         [101654.14 , 101654.14 , ..., 101654.14 , 101654.14 ]],
#
#        [[ 68572.766,  68572.766, ...,  68572.766,  68572.766],
#         [ 69468.58 ,  69451.33 , ...,  69497.6  ,  69483.96 ],
#         ...,
#         [101691.86 , 101691.65 , ..., 101692.39 , 101692.11 ],
#         [101750.58 , 101750.58 , ..., 101750.58 , 101750.58 ]],
#
#        ...,
#
#        [[ 67839.164,  67839.164, ...,  67839.164,  67839.164],
#         [ 68762.87 ,  68748.04 , ...,  68785.36 ,  68775.26 ],
#         ...,
#         [101413.72 , 101413.37 , ..., 101414.41 , 101414.06 ],
#         [101425.16 , 101425.16 , ..., 101425.16 , 101425.16 ]],
#
#        [[ 68421.73 ,  68421.73 , ...,  68421.73 ,  68421.73 ],
# ...

# %%
ps_ann = ps.mean(dim='time')

# %%
plt.contourf(ps_ann)

# %%
# Make the figure larger
fig2 = plt.figure(figsize=(11,8.5))

data=ps_ann
data, lons = add_cyclic_point(data, coord=ps_ann['lon'])

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())

# Make a filled contour plot
ax.contourf(lons, ps_ann['lat'], data,
            transform = ccrs.PlateCarree())

# Add coastlines
ax.coastlines()

ax.set_title("Surface pressure mean", 
             fontsize = 14)

# Define the xticks for longitude
ax.set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
lon_formatter = cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define the yticks for latitude
ax.set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
lat_formatter = cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

# %%
precc1 = ds2.PRECC

prect3_ann = ds1.PRECC.mean(dim='time') + ds1.PRECL.mean(dim='time')
prect3_ann = (prect3_ann*1000)*60*60*24

high = prect3_ann.max()

high
# Out:
# <xarray.DataArray ()>
# array(15.51751328)

# %%
#precc_ann = precc.mean(dim='time')
L = np.arange(0, 16, 1)
plt.contourf(prect3_ann)
plt.colorbar()

# %%
# Make the figure larger
fig3 = plt.figure(figsize=(11,8.5))

data=precc_ann
data, lons = add_cyclic_point(data, coord=precc_ann['lon'])

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())

# Make a filled contour plot
ax.contourf(lons, precc_ann['lat'], data,
            transform = ccrs.PlateCarree())

# Add coastlines
ax.coastlines()

ax.set_title("Convective precipitation rate (liq + ice) mean", 
             fontsize = 14)

# Define the xticks for longitude
ax.set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
lon_formatter = cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define the yticks for latitude
ax.set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
lat_formatter = cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 4>()
#       1 # Make the figure larger
#       2 fig3 = plt.figure(figsize=(11,8.5))
# ----> 4 data=precc_ann
#       5 data, lons = add_cyclic_point(data, coord=precc_ann['lon'])
#       7 # Set the axes using the specified map projection
#
# NameError: name 'precc_ann' is not defined

# %%
precl = ds2.PRECL
precl_ann = precl.mean(dim='time')
plt.contourf(precl_ann)

# %%
# Make the figure larger
fig4 = plt.figure(figsize=(11,8.5))

data=precl_ann
data, lons = add_cyclic_point(data, coord=precl_ann['lon'])

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())

# Make a filled contour plot
ax.contourf(lons, precl_ann['lat'], data,
            transform = ccrs.PlateCarree())

# Add coastlines
ax.coastlines()

ax.set_title("Large-scale (stable) precipitation rate (liq + ice) mean", 
             fontsize = 14)

# Define the xticks for longitude
ax.set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
lon_formatter = cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define the yticks for latitude
ax.set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
lat_formatter = cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

# %%
ps2 = ds2.PS # 100km
ps3 = ds3.PS # 25km

ps2_ann = ps2.mean(dim = 'time')
ps3_ann = ps3.mean(dim = 'time')

# %%
ps3_inter = ps3_ann.interp_like(ps2_ann)

# %%
fig = plt.figure(figsize=(11,8.5))

data = ps3_inter
data, lons = add_cyclic_point(data, coord=ps3_inter['lon'])

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())

# Make a filled contour plot
P1 = ax.contourf(lons, ps3_inter.lat, data,
            transform = ccrs.PlateCarree())

# Add coastlines
ax.coastlines()

# %%
ps_anom = ps3_inter - ps2_ann

plt.contourf(ps_anom)
plt.colorbar()
