# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

# %%
file = "/scratch/vreddy6/project_data/sst.mon.ltm.1991-2020.nc"
ds = xr.open_dataset(file)
# Out:
# /home/vreddy6/.conda/envs/clim_data/lib/python3.10/site-packages/xarray/coding/times.py:724: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/vreddy6/.conda/envs/clim_data/lib/python3.10/site-packages/xarray/core/indexing.py:557: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   array = array.get_duck_array()

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:             (lat: 89, lon: 180, time: 12, nbnds: 2)
# Coordinates:
#   * lat                 (lat) float32 88.0 86.0 84.0 82.0 ... -84.0 -86.0 -88.0
#   * lon                 (lon) float32 0.0 2.0 4.0 6.0 ... 354.0 356.0 358.0
#   * time                (time) object 0001-01-01 00:00:00 ... 0001-12-01 00:0...
# Dimensions without coordinates: nbnds
# Data variables:
#     climatology_bounds  (time, nbnds) datetime64[ns] ...
#     sst                 (time, lat, lon) float32 ...
#     valid_yr_count      (time, lat, lon) float32 ...
# Attributes: (12/38)
#     climatology:                    Climatology is based on 1971-2000 SST, Xu...
#     description:                    In situ data: ICOADS2.5 before 2007 and N...
#     keywords_vocabulary:            NASA Global Change Master Directory (GCMD...
#     keywords:                       Earth Science > Oceans > Ocean Temperatur...
#     instrument:                     Conventional thermometers
# ...

# %%
plt.contourf(ds['sst'][0,:,:])

# %%
plt.contourf(ds['sst'][0,-1::-1,:])
